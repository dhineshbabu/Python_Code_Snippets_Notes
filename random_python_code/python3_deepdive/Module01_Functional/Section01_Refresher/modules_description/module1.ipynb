# %% [markdown]
# # Modules

# %%
def func():
    a = 10
    return a

# %%
func
# Out:
# <function __main__.func()>

# %%
id(func)
# Out:
# 1879680049664

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'def func():\n    a = 10\n    return a',
#   'func',
#   'id(func)',
#   'globals()'],
#  '_oh': {2: <function __main__.func()>, 3: 1879680049664},
#  '_dh': ['c:\\Dhinesh_Official\\My_GitHub_Repos\\Python_Code_Snippets_Notes\\random_python_code\\python3_deepdive\\Module01_Functional\\Section01_Refresher\\modules_description'],
#  'In': ['',
#   'def func():\n    a = 10\n    return a',
#   'func',
#   'id(func)',
#   'globals()'],
#  'Out': {2: <function __main__.func()>, 3: 1879680049664},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001B5A5A78040>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x1b5a5a78970>,
# ...

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'def func():\n    a = 10\n    return a',
#   'func',
#   'id(func)',
#   'globals()',
#   'locals()'],
#  '_oh': {2: <function __main__.func()>, 3: 1879680049664, 4: {...}},
#  '_dh': ['c:\\Dhinesh_Official\\My_GitHub_Repos\\Python_Code_Snippets_Notes\\random_python_code\\python3_deepdive\\Module01_Functional\\Section01_Refresher\\modules_description'],
#  'In': ['',
#   'def func():\n    a = 10\n    return a',
#   'func',
#   'id(func)',
#   'globals()',
#   'locals()'],
#  'Out': {2: <function __main__.func()>, 3: 1879680049664, 4: {...}},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001B5A5A78040>>,
# ...

# %%
def func():
    a = 10
    b = 10
    print(locals())

func()
# Out:
# {'a': 10, 'b': 10}

# %%
# math module
import math 
print(math)
# Out:
# <module 'math' (built-in)>

# %%
import fractions
print(fractions)
# Out:
# <module 'fractions' from 'C:\\Python_310\\Python\\lib\\fractions.py'>

# %%
import sys
sys.modules
# Out:
# {'sys': <module 'sys' (built-in)>,
#  'builtins': <module 'builtins' (built-in)>,
#  '_frozen_importlib': <module '_frozen_importlib' (frozen)>,
#  '_imp': <module '_imp' (built-in)>,
#  '_thread': <module '_thread' (built-in)>,
#  '_warnings': <module '_warnings' (built-in)>,
#  '_weakref': <module '_weakref' (built-in)>,
#  '_io': <module '_io' (built-in)>,
#  'marshal': <module 'marshal' (built-in)>,
#  'nt': <module 'nt' (built-in)>,
#  'winreg': <module 'winreg' (built-in)>,
#  '_frozen_importlib_external': <module '_frozen_importlib_external' (frozen)>,
#  'time': <module 'time' (built-in)>,
#  'zipimport': <module 'zipimport' (frozen)>,
#  '_codecs': <module '_codecs' (built-in)>,
#  'codecs': <module 'codecs' from 'C:\\Python_310\\Python\\lib\\codecs.py'>,
#  'encodings.aliases': <module 'encodings.aliases' from 'C:\\Python_310\\Python\\lib\\encodings\\aliases.py'>,
#  'encodings': <module 'encodings' from 'C:\\Python_310\\Python\\lib\\encodings\\__init__.py'>,
# ...

# %%
math.__name__
# Out:
# 'math'

# %%
math.__dict__
# Out:
# {'__name__': 'math',
#  '__doc__': 'This module provides access to the mathematical functions\ndefined by the C standard.',
#  '__package__': '',
#  '__loader__': _frozen_importlib.BuiltinImporter,
#  '__spec__': ModuleSpec(name='math', loader=<class '_frozen_importlib.BuiltinImporter'>, origin='built-in'),
#  'acos': <function math.acos(x, /)>,
#  'acosh': <function math.acosh(x, /)>,
#  'asin': <function math.asin(x, /)>,
#  'asinh': <function math.asinh(x, /)>,
#  'atan': <function math.atan(x, /)>,
#  'atan2': <function math.atan2(y, x, /)>,
#  'atanh': <function math.atanh(x, /)>,
#  'ceil': <function math.ceil(x, /)>,
#  'copysign': <function math.copysign(x, y, /)>,
#  'cos': <function math.cos(x, /)>,
#  'cosh': <function math.cosh(x, /)>,
#  'degrees': <function math.degrees(x, /)>,
#  'dist': <function math.dist(p, q, /)>,
#  'erf': <function math.erf(x, /)>,
#  'erfc': <function math.erfc(x, /)>,
#  'exp': <function math.exp(x, /)>,
# ...

# %%
import fractions
print(sys.modules[fractions])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5012/1223494745.py in <module>
#       1 import fractions
# ----> 2 print(sys.modules[fractions])
#
# KeyError: <module 'fractions' from 'C:\\Python_310\\Python\\lib\\fractions.py'>

# %%
dir(fractions)
# Out:
# ['Decimal',
#  'Fraction',
#  '_PyHASH_INF',
#  '_PyHASH_MODULUS',
#  '_RATIONAL_FORMAT',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'math',
#  'numbers',
#  'operator',
#  're',
#  'sys']

# %%
# STANDARD LIBRARAY WILL BE IN THE "lib" MODULE IN PYTHON INSTALLATION FOLDER

# %%
import types
isinstance(fractions, types.ModuleType)
# Out:
# True

# %%
import sys

# %%
sys.prefix
# Out:
# 'C:\\Python_310\\Python'

# %%
sys.exec_prefix
# Out:
# 'C:\\Python_310\\Python'

# %%
# where does python look for imports
sys.path
# Out:
# ['c:\\Dhinesh_Official\\My_GitHub_Repos\\Python_Code_Snippets_Notes\\random_python_code\\python3_deepdive\\Module01_Functional\\Section01_Refresher\\modules_description',
#  'c:\\Users\\LENOVO\\.vscode\\extensions\\ms-toolsai.jupyter-2021.11.1001550889\\pythonFiles',
#  'c:\\Users\\LENOVO\\.vscode\\extensions\\ms-toolsai.jupyter-2021.11.1001550889\\pythonFiles\\lib\\python',
#  'C:\\Python_310\\Python\\python310.zip',
#  'C:\\Python_310\\Python\\DLLs',
#  'C:\\Python_310\\Python\\lib',
#  'C:\\Python_310\\Python',
#  '',
#  'C:\\Python_310\\Python\\lib\\site-packages',
#  'C:\\Python_310\\Python\\lib\\site-packages\\win32',
#  'C:\\Python_310\\Python\\lib\\site-packages\\win32\\lib',
#  'C:\\Python_310\\Python\\lib\\site-packages\\Pythonwin',
#  'C:\\Python_310\\Python\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\LENOVO\\.ipython']

# %% [markdown]
# Imports and importlib

# %%
import sys
sys
# Out:
# <module 'sys' (built-in)>

# %%
import collections
collections
# Out:
# <module 'collections' from 'C:\\Python_310\\Python\\lib\\collections\\__init__.py'>

# %%
import importlib
importlib
# Out:
# <module 'importlib' from 'C:\\Python_310\\Python\\lib\\importlib\\__init__.py'>

# %%
# we can assign variable name to builtin modules and we can use with importlib

mod_name = 'math'
importlib.import_module(mod_name)
# Out:
# <module 'math' (built-in)>

# %%
'math' in sys.modules
# Out:
# True

# %%
math2 = importlib.import_module(mod_name)

# %%
'math2' in globals()
# Out:
# True

# %%
id(math) == id(math2)
# Out:
# True

# %%
math.__spec__
# Out:
# ModuleSpec(name='math', loader=<class '_frozen_importlib.BuiltinImporter'>, origin='built-in')

# %%
import fractions
fractions.__spec__
# Out:
# ModuleSpec(name='fractions', loader=<_frozen_importlib_external.SourceFileLoader object at 0x000001B5A5AB2680>, origin='C:\\Python_310\\Python\\lib\\fractions.py')

# %%
sys.meta_path
# Out:
# [_frozen_importlib.BuiltinImporter,
#  _frozen_importlib.FrozenImporter,
#  _frozen_importlib_external.PathFinder,
# ...

# %%
import os
ext_module_path = os.environ['HOMEPATH']
file_abs_path = os.path.join(ext_module_path, 'module3.py')

with open(file_abs_path, 'w') as code_file:
    code_file.write('print("running inside module3")')

# %%
importlib.util.find_spec('module3') # it will not return nothing

# %%
sys.path.append(ext_module_path)

# %%
importlib.util.find_spec('module3')
# Out:
# ModuleSpec(name='module3', loader=<_frozen_importlib_external.SourceFileLoader object at 0x000001B5A5AB30A0>, origin='c:\\Users\\LENOVO\\module3.py')

# %%
import module3
# Out:
# running inside module3

# %%
sys.path
# Out:
# ['c:\\Dhinesh_Official\\My_GitHub_Repos\\Python_Code_Snippets_Notes\\random_python_code\\python3_deepdive\\Module01_Functional\\Section01_Refresher\\modules_description',
#  'c:\\Users\\LENOVO\\.vscode\\extensions\\ms-toolsai.jupyter-2021.11.1001550889\\pythonFiles',
#  'c:\\Users\\LENOVO\\.vscode\\extensions\\ms-toolsai.jupyter-2021.11.1001550889\\pythonFiles\\lib\\python',
#  'C:\\Python_310\\Python\\python310.zip',
#  'C:\\Python_310\\Python\\DLLs',
#  'C:\\Python_310\\Python\\lib',
#  'C:\\Python_310\\Python',
#  '',
#  'C:\\Python_310\\Python\\lib\\site-packages',
#  'C:\\Python_310\\Python\\lib\\site-packages\\win32',
#  'C:\\Python_310\\Python\\lib\\site-packages\\win32\\lib',
#  'C:\\Python_310\\Python\\lib\\site-packages\\Pythonwin',
#  'C:\\Python_310\\Python\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\LENOVO\\.ipython',
#  '\\Users\\LENOVO']

# %% [markdown]
# Import variants

# %%
import sys

for key in sorted(sys.modules.keys()):
    print(key)
# Out:
# IPython
# IPython.core
# IPython.core.alias
# IPython.core.application
# IPython.core.async_helpers
# IPython.core.autocall
# IPython.core.builtin_trap
# IPython.core.compilerop
# IPython.core.completer
# IPython.core.completerlib
# IPython.core.crashhandler
# IPython.core.debugger
# IPython.core.display
# IPython.core.display_trap
# IPython.core.displayhook
# IPython.core.displaypub
# IPython.core.error
# IPython.core.events
# IPython.core.excolors
# IPython.core.extensions
# IPython.core.formatters
# IPython.core.getipython
# IPython.core.history
# IPython.core.hooks
# IPython.core.inputtransformer2
# IPython.core.interactiveshell
# IPython.core.latex_symbols
# IPython.core.logger
# IPython.core.macro
# IPython.core.magic
# IPython.core.magic_arguments
# IPython.core.magics
# IPython.core.magics.auto
# IPython.core.magics.basic
# IPython.core.magics.code
# IPython.core.magics.config
# IPython.core.magics.display
# IPython.core.magics.execution
# IPython.core.magics.extension
# ...

# %%
'cmath' in sys.modules
# Out:
# False

# %%
'cmath' in globals()
# Out:
# False

# %%
from cmath import exp

# %%
'cmath' in globals()
# Out:
# False

# %%
'exp' in globals()
# Out:
# True

# %%
'cmath' in sys.modules
# Out:
# True

# %% [markdown]
#  Efficiency

# %%
def my_func(a):
    import math
    return math.sqrt(a)

# %%
## Reloading Modules
# importlib reload function will maintain the same memmory address after reloading modules

# %%
##  using __main__

# %%
sys.meta_path
# Out:
# [_frozen_importlib.BuiltinImporter,
#  _frozen_importlib.FrozenImporter,
#  _frozen_importlib_external.PathFinder,
# ...

# %%
sys.path
# Out:
# ['c:\\Dhinesh_Official\\My_GitHub_Repos\\Python_Code_Snippets_Notes\\random_python_code\\python3_deepdive\\Module01_Functional\\Section01_Refresher\\modules_description',
#  'c:\\Users\\LENOVO\\.vscode\\extensions\\ms-toolsai.jupyter-2021.11.1001550889\\pythonFiles',
#  'c:\\Users\\LENOVO\\.vscode\\extensions\\ms-toolsai.jupyter-2021.11.1001550889\\pythonFiles\\lib\\python',
#  'C:\\Python_310\\Python\\python310.zip',
#  'C:\\Python_310\\Python\\DLLs',
#  'C:\\Python_310\\Python\\lib',
#  'C:\\Python_310\\Python',
#  '',
#  'C:\\Python_310\\Python\\lib\\site-packages',
#  'C:\\Python_310\\Python\\lib\\site-packages\\win32',
#  'C:\\Python_310\\Python\\lib\\site-packages\\win32\\lib',
#  'C:\\Python_310\\Python\\lib\\site-packages\\Pythonwin',
#  'C:\\Python_310\\Python\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\LENOVO\\.ipython']

# %%
import collections
collections.__path__
# Out:
# ['C:\\Python_310\\Python\\lib\\collections']

# %%
import math
# print(math.__file__)
print(math.__spec__)
print(math.__name__)
print(math.__package__)
# Out:
# ModuleSpec(name='math', loader=<class '_frozen_importlib.BuiltinImporter'>, origin='built-in')
# math

# %%
# standard library
import fractions
print(fractions.__spec__)
print(fractions.__name__)
print(fractions.__package__)
print(fractions.__file__)
print(fractions.__dict__)
# Out:
# ModuleSpec(name='fractions', loader=<_frozen_importlib_external.SourceFileLoader object at 0x000002D2A51EAF50>, origin='C:\\Python_310\\Python\\lib\\fractions.py')
# fractions
#
# C:\Python_310\Python\lib\fractions.py
# ...
